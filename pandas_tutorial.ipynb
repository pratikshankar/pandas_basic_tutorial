# %%
import pandas as pd
df=pd.read_csv('E:\Datasets\housing.csv')
df
#df_xlsx=pd.read_excel('E:\Datasets\housing.xlsx')   reading an excel file
#df_text=pd.read_csv('E:\Datasets\housing.txt',delimeter="\t")  reading a text file
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
df.columns
df['median_income'].head()
df['median_income'].tail()
# Out:
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: median_income, dtype: float64

# %%
print(df['median_income'][0:5])
# Out:
# 0    8.3252
# 1    8.3014
# 2    7.2574
# 3    5.6431
# 4    3.8462
# Name: median_income, dtype: float64

# %%
print(df.iloc[1])#printing the row value

print(df.iloc[1,0])#printing the specific value of 0th column value of the 1st row
# Out:
# longitude              -122.22
# latitude                 37.86
# housing_median_age          21
# total_rooms               7099
# total_bedrooms            1106
# population                2401
# households                1138
# median_income           8.3014
# median_house_value      358500
# ocean_proximity       NEAR BAY
# Name: 1, dtype: object
#
# -122.22

# %%
for index,rows in df.iterrows():
    print(index,rows['longitude'])
# Out:
# 0 -122.23
# 1 -122.22
# 2 -122.24
# 3 -122.25
# 4 -122.25
# 5 -122.25
# 6 -122.25
# 7 -122.25
# 8 -122.26
# 9 -122.25
# 10 -122.26
# 11 -122.26
# 12 -122.26
# 13 -122.26
# 14 -122.26
# 15 -122.26
# 16 -122.27
# 17 -122.27
# 18 -122.26
# 19 -122.27
# 20 -122.27
# 21 -122.27
# 22 -122.27
# 23 -122.27
# 24 -122.27
# 25 -122.28
# 26 -122.28
# 27 -122.28
# 28 -122.28
# 29 -122.28
# 30 -122.28
# 31 -122.28
# 32 -122.27
# 33 -122.27
# 34 -122.27
# 35 -122.27
# 36 -122.27
# 37 -122.28
# 38 -122.26
# 39 -122.26
# 40 -122.26
# 41 -122.26
# 42 -122.26
# 43 -122.26
# 44 -122.26
# 45 -122.26
# 46 -122.26
# 47 -122.27
# 48 -122.26
# 49 -122.27
# 50 -122.27
# 51 -122.27
# 52 -122.27
# 53 -122.27
# 54 -122.28
# 55 -122.28
# 56 -122.28
# 57 -122.28
# 58 -122.28
# 59 -122.29
# 60 -122.29
# 61 -122.29
# 62 -122.29
# 63 -122.3
# 64 -122.3
# 65 -122.3
# 66 -122.3
# 67 -122.29
# 68 -122.3
# 69 -122.29
# 70 -122.29
# 71 -122.29
# 72 -122.29
# 73 -122.29
# 74 -122.29
# 75 -122.28
# 76 -122.28
# 77 -122.28
# ...

# %%
df.loc[df['housing_median_age']==15]  ##to have only those rows which have housing_median_age =15
# Out:
# longitude             512
# latitude              512
# housing_median_age    512
# total_rooms           512
# total_bedrooms        507
# population            512
# households            512
# median_income         512
# median_house_value    512
# ocean_proximity       512
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.sort_values(['total_bedrooms']).head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16171    -122.50     37.79                52.0          8.0             1.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 3126     -117.79     35.21                 4.0          2.0             2.0
# 16888    -122.37     37.60                26.0         15.0             3.0
# 12458    -114.62     33.62                26.0         18.0             3.0
#
#        population  households  median_income  median_house_value  \
# 16171        13.0         1.0        15.0001            500001.0
# 12286         8.0         2.0         1.6250             55000.0
# 3126          6.0         2.0         2.3750            137500.0
# 16888        11.0         3.0         5.0480            350000.0
# 12458         5.0         3.0         0.5360            275000.0
#
#       ocean_proximity
# 16171        NEAR BAY
# 12286          INLAND
# 3126           INLAND
# 16888      NEAR OCEAN
# ...

# %%
df.sort_values(['total_rooms','total_bedrooms'],ascending=False).head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13139    -121.44     38.43                 3.0      39320.0          6210.0
# 10309    -117.74     33.89                 4.0      37937.0          5471.0
# 9880     -121.79     36.64                11.0      32627.0          6445.0
# 6057     -117.78     34.03                 8.0      32054.0          5290.0
# 12201    -117.20     33.58                 2.0      30450.0          5033.0
#
#        population  households  median_income  median_house_value  \
# 13139     16305.0      5358.0         4.9516            153700.0
# 10309     16122.0      5189.0         7.4947            366300.0
# 9880      28566.0      6082.0         2.3087            118800.0
# 6057      15507.0      5050.0         6.0191            253900.0
# 12201      9419.0      3197.0         4.5936            174300.0
#
#       ocean_proximity
# 13139          INLAND
# 10309       <1H OCEAN
# 9880        <1H OCEAN
# 6057        <1H OCEAN
# ...

# %%
#### df['total']=df['col1']+df['col2']  to get the sum of 2 columns as a new coliumn in the dataset by the name total
##df=df.drop(columns=['total'])
#df['new colemn name']=df.iloc[:,staring column ,ending column +1].sum(axis=1)
#df.to_csv('file name.csv ')
#df.reset_index(drop=True,inplace=True)   drop drops the previous index and inplace saves the new reset index to the same dataframe without creating a copy 
##df.groupby(['columnn value'])
## df.mean()
